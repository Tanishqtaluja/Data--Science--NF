# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanishqtaluja/Data--Science--NF/blob/main/Ques_Bank.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Write a program to check whether a year is a leap year or not code
year = int(input("Enter year: "))

if year % 4 == 0:
    print("Leap Year")
else:
    print("Not Leap Year")
# Out:
# Enter year: 2001
# Not Leap Year

# %%
#Write a program to check whether a character is an uppercase letter, lowercase letter, digit, or special character
ch = input("Enter a character: ")

if ch.isupper():
    print("Uppercase Letter")

elif ch.islower():
    print("Lowercase Letter")

elif ch.isdigit():
    print("Digit")

else:
    print("Special Character")
# Out:
# Enter a character: Tanishq
# Special Character

# %%
#Write a program to calculate electricity bill using different unit slabs
unit = int(input("Enter electricity units: "))

if unit <= 100:
    bill = unit * 5

elif unit <= 200:
    bill = unit * 7

else:
    bill = unit * 10

print("Electricity Bill =", bill)
# Out:
# Enter electricity units: 44
# Electricity Bill = 220

# %%
#Write a program to determine whether a triangle is Equilateral, Isosceles, or Scalene
a = int(input())
b = int(input())
c = int(input())

if a == b == c:
    print("Equilateral")

elif a == b or b == c or a == c:
    print("Isosceles")

else:
    print("Scalene")
# Out:
# 2
# 2
# 2
# Equilateral

# %%
#Write a program to create a simple calculator using if-elif-else
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
op = input("Enter operator (+,-,*,/): ")

if op == "+":
    print(a + b)

elif op == "-":
    print(a - b)

elif op == "*":
    print(a * b)

elif op == "/":
    print(a / b)

else:
    print("Invalid Operator")
# Out:
# Enter first number: 55
# Enter second number: 56
# Enter operator (+,-,*,/): -
# -1

# %%
#Write a program to calculate income tax according to salary ranges
salary = int(input("Enter salary: "))

if salary <= 250000:
    tax = 0

elif salary <= 500000:
    tax = salary * 0.05

elif salary <= 1000000:
    tax = salary * 0.10

else:
    tax = salary * 0.20

print("Income Tax =", tax)
# Out:
# Enter salary: 500000
# Income Tax = 25000.0

# %%
#Write a program to check login authentication using username and password conditions
username = input("Enter username: ")
password = input("Enter password: ")

if username == "admin" and password == "1234":
    print("Login Successful")

else:
    print("Invalid Username or Password")
# Out:
# Enter username: tanishq
# Enter password: tanishq19
# Invalid Username or Password

# %%
#Write a program to determine whether a point lies in First quadrant, Second quadrant, Third quadrant, Fourth quadrant, On axis, or At origin
x = int(input())
y = int(input())

if x > 0 and y > 0:
    print("First")

elif x < 0 and y > 0:
    print("Second")

elif x < 0 and y < 0:
    print("Third")

elif x > 0 and y < 0:
    print("Fourth")

elif x == 0 and y == 0:
    print("Origin")

else:
    print("Axis")
# Out:
# 0
# 2
# Axis

# %%
#Write a program to assign grades based on marks and display distinction for high scores
marks = int(input("Enter marks: "))

if marks >= 90:
    print("Grade A - Distinction")

elif marks >= 75:
    print("Grade B")

elif marks >= 50:
    print("Grade C")

else:
    print("Fail")
# Out:
# Enter marks: 88
# Grade B

# %%
# Program to find the largest and smallest elements in a list

numbers = [12, 45, 7, 89, 23]

largest = max(numbers)
smallest = min(numbers)

print("Largest element is:", largest)
print("Smallest element is:", smallest)
# Out:
# Largest element is: 89
# Smallest element is: 7

# %%
# Program to reverse a list without using built-in reverse functions

numbers = [1, 2, 3, 4, 5]

reversed_list = []

for i in range(len(numbers)-1, -1, -1):
    reversed_list.append(numbers[i])

print("Original list:", numbers)
print("Reversed list:", reversed_list)
# Out:
# Original list: [1, 2, 3, 4, 5]
# Reversed list: [5, 4, 3, 2, 1]

# %%
#Write a program to count the occurrence of an element in a tuple
t = (1, 2, 3, 2, 4, 2)

x = 2
count = 0

for i in t:
    if i == x:
        count += 1

print("Occurrence =", count)
# Out:
# Occurrence = 3

# %%
#Write a program to convert a tuple into a list and a list into a tuple
t = (1, 2, 3)
l = list(t)                                         # Tuple to List

print("List:", l)

l1 = [4, 5, 6]
t1 = tuple(l1)                                           # List to Tuple

print("Tuple:", t1)
# Out:
# List: [1, 2, 3]
# Tuple: (4, 5, 6)

# %%
#Write a program to sort a list of tuples based on tuple values
list1 = [(3, 4), (1, 2), (5, 1)]

list1.sort()

print(list1)
# Out:
# [(1, 2), (3, 4), (5, 1)]

# %%
#Write a program to create a dictionary from two lists: one of keys and one of values
keys = ["a", "b", "c"]
values = [1, 2, 3]

d = dict(zip(keys, values))

print(d)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
#Merge two dictionaries into one
d1 = {"a": 1, "b": 2}
d2 = {"c": 3, "d": 4}

d1.update(d2)

print(d1)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
#Write a program to sort a dictionary by its values
d = {"a": 3, "b": 1, "c": 2}

sorted_dict = dict(sorted(d.items(), key=lambda x: x[1]))

print(sorted_dict)
# Out:
# {'b': 1, 'c': 2, 'a': 3}

# %%
#given two sets, check if one set is a subset of another
a = {1, 2, 3}
b = {1, 2, 3, 4, 5}

if a.issubset(b):
    print("a is a subset of b")
else:
    print("a is not a subset of b")
# Out:
# a is a subset of b

# %%
#Write a program to check whether two lists have at least one common element using sets
list1 = [1, 2, 3]
list2 = [3, 4, 5]

if set(list1) & set(list2):
    print("Common element found")
else:
    print("No common element")
# Out:
# Common element found
